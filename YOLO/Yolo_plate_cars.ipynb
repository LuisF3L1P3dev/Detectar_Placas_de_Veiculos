# %% [markdown]
# # 1-Importações

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import os
from IPython.display import Image, clear_output # Mostrar as imagens

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12332, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 12332 (delta 27), reused 15 (delta 3), pack-reused 12281
# Receiving objects: 100% (12332/12332), 12.08 MiB | 17.43 MiB/s, done.
# Resolving deltas: 100% (8502/8502), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 24.0 MB/s
# Setup complete. Using torch 1.11.0+cu113 (Tesla T4)

# %% [markdown]
# # 2- Dataset treinamento:

# %%
# %cd ..
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip Dataset.zip

# %% [markdown]
# # 3- Treinando o modelo customizado da YOLOV5

# %%
# %pip install -qr requirements.txt

# %%
# !python train.py --img 980 --batch 28 --epochs 10 --data /content/yolov5/data/custom_data.yaml --weights /content/drive/MyDrive/nadic/YOLO/yolov5s6.pt

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %% [markdown]
# Código para ativar o click no colab a cada 10 minutos para você não ser expulso do colab

# %%
function ClickConnect(){
console.log("Working"); 
document
  .querySelector('#top-toolbar > colab-connect-button')
  .shadowRoot.querySelector('#connect')
  .click() 
}
setInterval(ClickConnect,60000)

# %% [markdown]
# # Rodando os pesos e fazendo a **inferência**

# %% [markdown]
# Onde tem path deve-se colocar o caminho até a mídia que você quer identificar

# %%
# !python detect.py --weights /content/drive/MyDrive/nadic/YOLO/best.pt --conf 0.70 --source /content/drive/MyDrive/Workshop_Nadic/ifrn_1.jpg --save-crop
